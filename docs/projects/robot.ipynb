# %% [markdown]
# # Robot
#
# * *ide49* custom install to set `dtoverlay`

# %%
# %%bash
#
# cd $IOT_PROJECTS
# svn checkout https://github.com/iot49/iot49.org/trunk/docs/projects/robot
