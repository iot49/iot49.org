# %% [markdown]
# # Nginx
#
# The `nginx` configuration is in `/etc/nginx`. It is also mounted to `/service-config/nginx` in *jupyter*, *duplicati*, and *code-server* services.
#
# A default configuration (files `nginx.conf` and `htpasswd`) is installed when the file `.config_v1` is not present. This file is automatically generated after the default config is installed. After that user customizations can be applied that won't be overwritten. Delete `.config_v1` to upgrade to the latest default configuration when the service is restarted.
#
# Static content is served from `/home/iot/.html`. Files in this directory are available at http://iot49.local (no password protection).
#
# `index.html` is installed by default. You can edit it, but if you delete it, it will be recreated automatically when the service is restarted.
